# %%
class tiendaonline:                            #primero creamos la clase


    def _init_(self):       #solo pongo el self porque es el unico elemento que no varia
        
        self.inventario = []            #lista de 2 diccionario vacio al principio
        self.ventas_totales = 0.0   
                                             #0.0 ya que es float numero decimal y es con punto, no coma  
    def agregar_producto(self, lista_inventario):
        if camisa in lista_inventario:
            print("ese producto esta")

# %%
mi_tienda = tiendaonline()  #2º paso creo el nombre de mi tienda

# %%
mi_tienda.__dict__                #no sale nada porque está vacia ahora mismo
# Out:
# {}

# %%
mi_tienda.agregar_producto("nombre","precio","cantidad")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[244], line 1
# ----> 1 mi_tienda.agregar_producto("nombre","precio","cantidad")
#
# TypeError: tiendaonline.agregar_producto() takes 2 positional arguments but 4 were given

# %% [markdown]
# #CREO LOS DICCIONARIOS PARA METERLOS EN UNA LISTA

# %%
dict_productos = {"nombre":"camisa", "precio": 20, "cantidad": 40}

# %%
dict_productos2 = {"nombre":"pantalon", "precio":30, "cantidad": 30}

# %%
lista_inventario = [dict_productos, dict_productos2]
print(lista_inventario)
# Out:
# [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40}, {'nombre': 'pantalon', 'precio': 30, 'cantidad': 30}]

# %% [markdown]
# VAMOS A EMPEZAR DE 0

# %% [markdown]
# #creamos la clase y ponemos los atributos. el inventario lo piden vacio y las vents tienen que inicar en 0

# %%
class Tiendaonline:

    def __init__(self):
        self.inventario = []
        self.ventas_totales = 0.0
    
    def agregar_producto(self, nombre, precio, cantidad):
        producto_nuevo = {'nombre': nombre, 'precio': precio, 'cantidad': cantidad}
        
        for producto in self.inventario:          #ver si el prodcuto existe y añado cantidad o añado prodc
            if producto['nombre'] == nombre:
                producto['cantidad'] += cantidad
                                         
        else:
            nuevo_producto = {'nombre': nombre,'precio': precio,'cantidad': cantidad}
            self.inventario.append(producto_nuevo)             
        
        for producto in self.inventario:          #ver si el prodcuto existe y añado cantidad o añado prodc
            if producto['nombre'] == nombre:
                producto['cantidad'] += cantidad
                return                               #evito que se duplique el articulo y paro el metedo
                
            else:
                nuevo_producto = {'nombre': nombre,'precio': precio,'cantidad': cantidad}
                
    def ver_inventario(self):                    #para ver iventario
        for producto in self.inventario:
            print(f"Nombre: {producto['nombre']},"f"Precio: ${producto['precio']},"f"Cantidad: {producto['cantidad']}")
    
    def buscar_producto(self, nombre):
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                print(f"Nombre: {producto['nombre']},"f"Precio: ${producto['precio']},"f"Cantidad: {producto['cantidad']}")
    
    def actualizar_stock(self, nombre, cantidad):
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                producto['cantidad'] += cantidad
                print("Stock actualizado")
                return
            else:
                print(" no esta en el inventario")
        
    def eliminar_producto(self, nombre):
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                self.inventario.remove(producto)
                print("producto eliminado")
                return
            else:
                print("Producto no encontrado en el inventario")

    def calcular_valor_inventario(self): 
        total=0                                                           #empezamos nuestra tienda con 0 euros
        
        for producto in self.inventario:
            total += producto["precio"] * producto["cantidad"] 
            print("Valor total del inventario:", total)                 #total calculado
            
                             
    def agregar_mas_productos(self, lista_productos):

        for productos in lista_productos:

            self.agregar_producto(productos["nombre"], productos["precio"], productos["cantidad"])
                 
                
                #pasar a limpio
        #el print tiene que ir aqui debajo del for porque si no me suma el valor de cada producto no el total

# %%
mi_tienda=Tiendaonline()    #no me deja poner un nombre

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [], 'ventas_totales': 0.0}

# %%
mi_tienda.agregar_producto("camisa",20, 40)

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 80}],
#  'ventas_totales': 0.0}

# %%
mi_tienda.agregar_producto("pantalon",20, 40)

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 80},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 80}],
#  'ventas_totales': 0.0}

# %%
mi_tienda.agregar_producto("pantalon",20, 40)         #añado otra vez pantalon

# %%
mi_tienda.__dict__                                     #compruebo que se ha añadido
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 80},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 160},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 40}],
#  'ventas_totales': 0.0}

# %%
mi_tienda.agregar_producto("falda",10, 30)                 #añado nuevo producto

# %%
mi_tienda.__dict__                        #compruebo que se ha añadido
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 80},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 160},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 40},
#   {'nombre': 'falda', 'precio': 10, 'cantidad': 60}],
#  'ventas_totales': 0.0}

# %%
mi_tienda.agregar_producto("jersey",50, 17)

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 80},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 160},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 40},
#   {'nombre': 'falda', 'precio': 10, 'cantidad': 60},
#   {'nombre': 'jersey', 'precio': 50, 'cantidad': 34}],
#  'ventas_totales': 0.0}

# %% [markdown]
# #ver inventario    ojo!! el jersey no lo he metido en el proyecto era para probar con otra prenda porque se me duplican y no me cuadran  las cantidades

# %%
mi_tienda.ver_inventario()
# Out:
# Nombre: camisa,Precio: $20,Cantidad: 80
# Nombre: pantalon,Precio: $20,Cantidad: 160
# Nombre: pantalon,Precio: $20,Cantidad: 40
# Nombre: falda,Precio: $10,Cantidad: 60
# Nombre: jersey,Precio: $50,Cantidad: 34

# %% [markdown]
# #buscar producto

# %%
mi_tienda.buscar_producto("camisa")
# Out:
# Nombre: camisa,Precio: $20,Cantidad: 80

# %%
mi_tienda.buscar_producto("pantalon")             #me sale 2 veces ( se me ha duplicado)
# Out:
# Nombre: pantalon,Precio: $20,Cantidad: 160
# Nombre: pantalon,Precio: $20,Cantidad: 40

# %%
mi_tienda.buscar_producto("falda")
# Out:
# Nombre: falda,Precio: $10,Cantidad: 60

# %% [markdown]
# #comprobar stock

# %%
mi_tienda.actualizar_stock ("camisa" , 50)
# Out:
# Stock actualizado

# %%
mi_tienda.buscar_producto("camisa")                     #compruebo que se ha actualizado bien el stock
# Out:
# Nombre: camisa,Precio: $20,Cantidad: 130

# %%
mi_tienda.actualizar_stock ("kimono" , -20)
# Out:
#  no esta en el inventario
#  no esta en el inventario
#  no esta en el inventario
#  no esta en el inventario
#  no esta en el inventario

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 130},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 160},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 40},
#   {'nombre': 'falda', 'precio': 10, 'cantidad': 60},
#   {'nombre': 'jersey', 'precio': 50, 'cantidad': 34}],
#  'ventas_totales': 0.0}

# %%
mi_tienda.eliminar_producto ("falda")                  #me da todo el rato error con todo lo que pruebo .remove .pop etc
# Out:
# Producto no encontrado en el inventario
# Producto no encontrado en el inventario
# Producto no encontrado en el inventario
# producto eliminado

# %%
mi_tienda.ver_inventario()
# Out:
# Nombre: camisa,Precio: $20,Cantidad: 130
# Nombre: pantalon,Precio: $20,Cantidad: 160
# Nombre: pantalon,Precio: $20,Cantidad: 40
# Nombre: jersey,Precio: $50,Cantidad: 34

# %%
mi_tienda.eliminar_producto ("calcetines")
# Out:
# Producto no encontrado en el inventario
# Producto no encontrado en el inventario
# Producto no encontrado en el inventario
# Producto no encontrado en el inventario

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 130},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 160},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 40},
#   {'nombre': 'jersey', 'precio': 50, 'cantidad': 34}],
#  'ventas_totales': 0.0}

# %%
mi_tienda.calcular_valor_inventario()
# Out:
# Valor total del inventario: 2600
# Valor total del inventario: 5800
# Valor total del inventario: 6600
# Valor total del inventario: 8300

# %%
productos_prueba = [{"nombre": "leotardos", "precio": 5, "cantidad": 20},
    {"nombre": "sudadera", "precio": 60, "cantidad": 100},
    {"nombre": "gorra", "precio": 10,"cantidad": 50},{"nombre": "pijama", "precio": 25, "cantidad":50}]

# %%
mi_tienda.agregar_mas_productos(productos_prueba)

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 130},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 160},
#   {'nombre': 'pantalon', 'precio': 20, 'cantidad': 40},
#   {'nombre': 'jersey', 'precio': 50, 'cantidad': 34},
#   {'nombre': 'leotardos', 'precio': 5, 'cantidad': 40},
#   {'nombre': 'sudadera', 'precio': 60, 'cantidad': 200},
#   {'nombre': 'gorra', 'precio': 10, 'cantidad': 100},
#   {'nombre': 'pijama', 'precio': 25, 'cantidad': 100}],
#  'ventas_totales': 0.0}
