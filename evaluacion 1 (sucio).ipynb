# %%
class tiendaonline:                            #primero creamos la clase


    def _init_(self):       #solo pongo el self porque es el unico elemento que no varia
        
        self.inventario = []            #lista de 2 diccionario vacio al principio
        self.ventas_totales = 0.0   
                #0.0 ya que es float numero decimal y es con punto, no coma  
     def agregar_producto(self, lista_inventario):
        if producto in lista_inventario:
            print("ese producto esta")
# Out:
#   File <string>:9
#     def agregar_producto(self, lista_inventario):
#                                                  ^
# IndentationError: unindent does not match any outer indentation level

# %%
mi_tienda = tiendaonline()  #2º paso creo el nombre de mi tienda

# %%
mi_tienda.__dict__                #no sale nada porque está vacia ahora mismo
# Out:
# {}

# %% [markdown]
# #CREO LOS DICCIONARIOS PARA METERLOS EN UNA LISTA

# %%
dict_productos = {"nombre":"camisa", "precio": 20, "cantidad": 40}

# %%
dict_productos2 = {"nombre":"pantalon", "precio":30, "cantidad": 30}

# %%
lista_inventario = [dict_productos, dict_productos2]
print(lista_inventario)
# Out:
# [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40}, {'nombre': 'pantalon', 'precio': 30, 'cantidad': 30}]

# %%
mi_tienda=tiendaonline()

for producto in lista_inventario:
    mi_tienda.agregar_producto()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 4
#       1 mi_tienda=tiendaonline()
#       3 for producto in lista_inventario:
# ----> 4     mi_tienda.agregar_producto()
#
# AttributeError: 'tiendaonline' object has no attribute 'agregar_producto'

# %%
# Pasamos la lista al método
inventario.agregar_productos(lista_inventario)
print(inventario.productos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 # Pasamos la lista al método
# ----> 2 inventario.agregar_productos(lista_inventario)
#       3 print(inventario.productos)
#
# NameError: name 'inventario' is not defined

# %%
def agregar_producto(self, lista_inventario):
        if producto in self.lista_inventario:
            print("ese producto esta")
