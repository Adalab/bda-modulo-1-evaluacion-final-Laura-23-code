# %%
class Tiendaonline:

    def __init__(self):
        self.inventario = []
        self.ventas_totales = 0.0
    
    def agregar_producto(self, nombre, precio, cantidad):
        producto_nuevo = {'nombre': nombre, 'precio': precio, 'cantidad': cantidad}
        self.inventario.append(producto_nuevo)
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                producto['cantidad'] = cantidad
                return
            
           
    def ver_inventario(self):                   
        for producto in self.inventario:
            print(f"Nombre: {producto['nombre']},"f"Precio: ${producto['precio']},"f"Cantidad: {producto['cantidad']}")
            
                
    def buscar_producto(self, nombre):
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                print(f"Nombre: {producto['nombre']},"f"Precio: ${producto['precio']},"f"Cantidad: {producto['cantidad']}")
                return
        else:
            print("el producto no existe")

    def actualizar_stock(self, nombre, cantidad):
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                producto['cantidad'] += cantidad
                print("Stock actualizado")
                return
        else:
                print(" no esta en el inventario")
    
    def eliminar_producto(self, nombre):
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                self.inventario.remove(producto)
                print("producto eliminado")
                return
        else:
                print("Producto no encontrado en el inventario")

    def calcular_valor_inventario(self): 
        total=0                                                           
        
        for producto in self.inventario:
            total += producto["precio"] * producto["cantidad"] 
        print("Valor total del inventario:", total)

# %%
mi_tienda = Tiendaonline()

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [], 'ventas_totales': 0.0}

# %% [markdown]
# #agregar productos

# %%
mi_tienda.agregar_producto("camisa",20, 40)

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40}],
#  'ventas_totales': 0.0}

# %%
mi_tienda.agregar_producto("pantalon",35, 72)

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40},
#   {'nombre': 'pantalon', 'precio': 35, 'cantidad': 72}],
#  'ventas_totales': 0.0}

# %%
mi_tienda.agregar_producto("vestido",15, 18)

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40},
#   {'nombre': 'pantalon', 'precio': 35, 'cantidad': 72},
#   {'nombre': 'vestido', 'precio': 15, 'cantidad': 18}],
#  'ventas_totales': 0.0}

# %%
mi_tienda.agregar_producto("falda",10, 30)

# %%
mi_tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40},
#   {'nombre': 'pantalon', 'precio': 35, 'cantidad': 72},
#   {'nombre': 'vestido', 'precio': 15, 'cantidad': 18},
#   {'nombre': 'falda', 'precio': 10, 'cantidad': 30}],
#  'ventas_totales': 0.0}

# %% [markdown]
# #ver inventario

# %%
mi_tienda.ver_inventario()
# Out:
# Nombre: camisa,Precio: $20,Cantidad: 40
# Nombre: pantalon,Precio: $35,Cantidad: 72
# Nombre: vestido,Precio: $15,Cantidad: 18
# Nombre: falda,Precio: $10,Cantidad: 30

# %% [markdown]
# #buscar producto

# %%
mi_tienda.buscar_producto("camisa")
# Out:
# Nombre: camisa,Precio: $20,Cantidad: 40

# %%
mi_tienda.buscar_producto("pantalon")
# Out:
# Nombre: pantalon,Precio: $35,Cantidad: 72

# %%
mi_tienda.buscar_producto("kimono")
# Out:
# el producto no existe

# %% [markdown]
# #compruebo stock

# %%
mi_tienda.actualizar_stock ("camisa" , 50)
# Out:
# Stock actualizado

# %%
mi_tienda.buscar_producto("camisa")
# Out:
# Nombre: camisa,Precio: $20,Cantidad: 90

# %%
mi_tienda.actualizar_stock ("falda" , -20)
# Out:
# Stock actualizado

# %%
mi_tienda.buscar_producto("falda")
# Out:
# Nombre: falda,Precio: $10,Cantidad: 10

# %%
mi_tienda.actualizar_stock ("kimono" , -20)
# Out:
#  no esta en el inventario

# %% [markdown]
# #eliminar producto

# %%
mi_tienda.eliminar_producto ("falda")
# Out:
# producto eliminado

# %%
mi_tienda.ver_inventario()
# Out:
# Nombre: camisa,Precio: $20,Cantidad: 90
# Nombre: pantalon,Precio: $35,Cantidad: 72
# Nombre: vestido,Precio: $15,Cantidad: 18

# %%
mi_tienda.eliminar_producto ("calcetines")
# Out:
# Producto no encontrado en el inventario

# %% [markdown]
# #calcular valor del inventario

# %%
mi_tienda.calcular_valor_inventario()
# Out:
# Valor total del inventario: 4590
